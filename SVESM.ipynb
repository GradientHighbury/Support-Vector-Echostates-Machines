# %%
from main import main_esm,main_svesm

# %%
class InputData:
    def __init__(self):
        self.length=8000
        self.embedded_dim=4
        self.delay=6
        self.horizon=84
        self.reservior_dim=200
        self.spectral_radius=0.9
        self.input_scale=0.5
        self.sparsity=0.9
        self.leak_rate=1.0
        self.seed=42
        self.epochs=100
        self.lr=1e-4
        self.weight_deacy=1e-4
        self.washout=50


input_data= InputData()

# %%
#only ESN
main_esm(input_data)
# Out:
# /home/section/Desktop/Files/MTECH IIT/Git projects/Projects/Support-Vector-Echostates-Machines/svsm/lib/python3.10/site-packages/torch/cuda/__init__.py:180: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# cpu
# Epoch 001Train MSE: 0.665670 |Val NRMSE: 0.817007
# Epoch 010Train MSE: 0.398014 |Val NRMSE: 0.652370
# Epoch 020Train MSE: 0.280268 |Val NRMSE: 0.550247
# Epoch 030Train MSE: 0.242775 |Val NRMSE: 0.516818
# Epoch 040Train MSE: 0.232255 |Val NRMSE: 0.508010
# Epoch 050Train MSE: 0.228823 |Val NRMSE: 0.504789
# Epoch 060Train MSE: 0.226547 |Val NRMSE: 0.504651
# Epoch 070Train MSE: 0.223311 |Val NRMSE: 0.499754
# Epoch 080Train MSE: 0.221515 |Val NRMSE: 0.497011
# Epoch 090Train MSE: 0.220298 |Val NRMSE: 0.494698
# Epoch 100Train MSE: 0.217320 |Val NRMSE: 0.492265
#
# Test NRMSE: 0.479425
#
# Sample predictions:
# true= 1.4010 | pred= 0.7721
# true= 0.2217 | pred= 0.6581
# true= 0.8437 | pred= 0.7146
# true=-0.4641 | pred=-0.0586
# true= 0.0150 | pred= 0.9117
# true= 0.8815 | pred= 0.0548
# true= 0.7576 | pred= 0.3711
# true= 1.5210 | pred= 0.9620
# true=-1.1544 | pred=-0.6738
# true= 0.5457 | pred=-0.0905

# %%
#SVESM
main_svesm(input_data)
# Out:
# cpu
# Running Iteration:->  1/12
# Running Iteration:->  2/12
# Running Iteration:->  3/12
# Running Iteration:->  4/12
# Running Iteration:->  5/12
# Running Iteration:->  6/12
# Running Iteration:->  7/12
# Running Iteration:->  8/12
# Running Iteration:->  9/12
# Running Iteration:->  10/12
# Running Iteration:->  11/12
# Running Iteration:->  12/12
# Best SVR config: {'C': 50.0, 'epsilon': 0.01}
# Best Validation NRMSE: 0.258125
# Test NRMSE: 0.249745
# Number of support vectors: 4660
