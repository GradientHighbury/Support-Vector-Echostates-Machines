# %%
from main import main_esm,main_svesm

# %%
class InputData:
    def __init__(self):
        self.length=8000
        self.embedded_dim=4
        self.delay=6
        self.horizon=84
        self.reservior_dim=200
        self.spectral_radius=0.9
        self.input_scale=0.5
        self.sparsity=0.9
        self.leak_rate=1.0
        self.seed=42
        self.epochs=100
        self.lr=1e-4
        self.weight_deacy=1e-4
        self.washout=50


input_data= InputData()

# %%
#only ESN
main_esm(input_data)
# Out:
# cpu
# Epoch 001Train MSE: 0.650607 |Val NRMSE: 0.759003
# Epoch 010Train MSE: 0.250036 |Val NRMSE: 0.538011
# Epoch 020Train MSE: 0.216085 |Val NRMSE: 0.505698
# Epoch 030Train MSE: 0.208134 |Val NRMSE: 0.496834
# Epoch 040Train MSE: 0.203982 |Val NRMSE: 0.492528
# Epoch 050Train MSE: 0.199826 |Val NRMSE: 0.483417
# Epoch 060Train MSE: 0.194993 |Val NRMSE: 0.478370
# Epoch 070Train MSE: 0.190443 |Val NRMSE: 0.474266
# Epoch 080Train MSE: 0.187118 |Val NRMSE: 0.473879
# Epoch 090Train MSE: 0.184190 |Val NRMSE: 0.465272
# Epoch 100Train MSE: 0.179743 |Val NRMSE: 0.460247
#
# Test NRMSE: 0.446921
#
# Sample predictions:
# true= 0.6271 | pred= 0.2103
# true= 0.6320 | pred= 1.0755
# true= 0.5256 | pred= 1.0521
# true= 1.3666 | pred= 0.9703
# true= 0.7978 | pred= 0.1926
# true= 0.9970 | pred= 0.6833
# true= 0.0564 | pred= 0.7587
# true=-0.8278 | pred=-0.5294
# true= 0.3546 | pred=-0.3257
# true= 0.9090 | pred= 0.9874

# %%
#SVESM
main_svesm(input_data)
